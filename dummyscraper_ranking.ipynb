# %%
# !pip install --upgrade numpy==1.26.4
# !pip install --upgrade gensim==4.3.3
# !pip install --upgrade scipy==1.13.1
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: gensim==4.3.3 in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim==4.3.3) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim==4.3.3) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim==4.3.3) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim==4.3.3) (1.17.2)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from scipy==1.13.1) (1.26.4)

# %%
import requests
from bs4 import BeautifulSoup

def scrape_google_news(query, num_results=20):
    query = query.replace(' ', '+')
    url = f"https://www.google.com/search?q={query}&tbm=nws&num={num_results}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36"
    }

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")

    news_results = []
    for el in soup.select("div.SoaBEf"):
        try:
            link = el.find("a")["href"]
            title = el.select_one("div.MBeuO").get_text()
            snippet = el.select_one(".GI74Re").get_text()
            date = el.select_one(".LfVVr").get_text()
            source = el.select_one(".NUnG9d span").get_text()
            news_results.append({
                "title": title,
                "link": link,
                "snippet": snippet,
                "date": date,
                "source": source
            })
        except Exception:
            continue

    return news_results

# Example usage:
if __name__ == "__main__":
    topic = "artificial intelligence"
    articles = scrape_google_news(topic, num_results=20)
    for i, article in enumerate(articles, 1):
        print(f"{i}. {article['title']}")
        print(f"   Source: {article['source']}")
        print(f"   Date: {article['date']}")
        print(f"   Link: {article['link']}")
        print(f"   Snippet: {article['snippet']}\n")
# Out:
# 1. Advanced AI suffers ‘complete accuracy collapse’ in face of complex problems, study finds | Artificial intelligence (AI)
#    Source: The Guardian
#    Date: 1 day ago
#    Link: https://www.theguardian.com/technology/2025/jun/09/apple-artificial-intelligence-ai-study-collapse
#    Snippet: 'Pretty devastating' Apple paper raises doubts about race to reach stage of AI at which it matches human intelligence.
#
# 2. Protests Against Artificial Intelligence Planned For Annecy Animation Fest
#    Source: Deadline
#    Date: 9 hours ago
#    Link: https://deadline.com/2025/06/artificial-intelligence-protests-planned-for-annecy-festival-1236428535/
#    Snippet: Artificial Intelligence protests are planned At Annecy Animation Festival and a group of unions will read out a statement against its...
#
# 3. XNA’s new parking service features artificial intelligence
#    Source: Talk Business & Politics
#    Date: 22 hours ago
#    Link: https://talkbusiness.net/2025/06/xnas-new-parking-service-features-artificial-intelligence/
#    Snippet: Northwest Arkansas National Airport (XNA) in Highfill has launched a parking service in partnership with Metropolis Technologies Inc.,...
#
# 4. Texas A&M now offering ‘Artificial Intelligence and Business’ minor
#    Source: KBTX News 3
#    Date: 17 hours ago
#    Link: https://www.kbtx.com/2025/06/09/texas-am-now-offering-artificial-intelligence-business-minor/
#    Snippet: Focus at Four: Mays Business School launches new program about artificial intelligence in business.
#
# 5. ChatGPT is down - here's everything we know about the outage
#    Source: TechRadar
#    Date: 9 minutes ago
#    Link: https://www.techradar.com/news/live/chatgpt-down-june-10
#    Snippet: ChatGPT is experiencing a major outage as users across the internet report problems with OpenAI's chatbot. Techradar is covering the...
#
# 6. How the WSJ is using artificial intelligence
#    Source: Talking Biz News
#    Date: 1 day ago
#    Link: https://talkingbiznews.com/media-news/how-the-wsj-is-using-artificial-intelligence/
#    Snippet: Sarah Scire of Nieman Lab writes about how The Wall Street Journal is using artificial intelligence. Scire writes, “Over at The Wall Street...
#
# 7. Amazon invests historic $20 billion for artificial intelligence infrastructure in Pa.
#    Source: Pittsburgh Post-Gazette
#    Date: 19 hours ago
#    Link: https://www.post-gazette.com/business/tech-news/2025/06/09/amazon-srtificial-intelligence-shapiro-invest/stories/202506090047
#    Snippet: Amazon will invest at least $20 billion to develop artificial intelligence “innovation campuses” across the commonwealth, Gov.
#
# 8. Algoworks Launches as Global Artificial Intelligence (AI), Engineering Services and Experience Transformation Leader
#    Source: Business Wire
#    Date: 4 hours ago
#    Link: https://www.businesswire.com/news/home/20250609690407/en/Algoworks-Launches-as-Global-Artificial-Intelligence-AI-Engineering-Services-and-Experience-Transformation-Leader
#    Snippet: Today, Algoworks Inc. announced the completion of its merger combining FROM Digital and Algoworks Solutions under private-equity (PE) owner...
#
# 9. Is This Artificial Intelligence (AI) Stock Still a Buy?
#    Source: Nasdaq
#    Date: 5 hours ago
#    Link: https://www.nasdaq.com/articles/artificial-intelligence-ai-stock-still-buy
#    Snippet: Since artificial intelligence (AI) is built on data, Snowflake (NYSE: SNOW) has excellent prospects for its products and services.
#
# 10. Artificial intelligence, artificial support: Google buys new friends in Parliament
#    Source: Monthly Review
#    Date: 4 hours ago
#    Link: https://mronline.org/2025/06/10/artificial-intelligence-artificial-support-google-buys-new-friends-in-parliament/
#    Snippet: SOLOMON HUGHES reveals how six MPs enjoyed £400-£600 hospitality at Ditchley Park for Google's 'AI parliamentary scheme' — supposedly to...
#
# 11. University releases proposed guidelines for artificial intelligence in teaching, learning, open to community feedback
#    Source: The Daily Texan
#    Date: 11 hours ago
#    Link: https://thedailytexan.com/2025/06/09/university-releases-proposed-guidelines-for-artificial-intelligence-in-teaching-learning-open-to-community-feedback/
#    Snippet: The University's proposed Responsible Adoption of Artificial Intelligence Tools for Teaching and Learning is open for feedback online for...
#
# 12. Being Intelligent with Artificial Intelligence
#    Source: Dordt University
#    Date: 23 hours ago
#    Link: https://www.dordt.edu/news/being-intelligent-with-artificial-intelligence
#    Snippet: By Jennifer Vermeer. Artificial intelligence (AI) continues to transform how we live and collaborate. Dordt faculty and alumni are...
#
# 13. Milwaukee Independent emerges as a Wisconsin leader for reporting on artificial intelligence
#    Source: Milwaukee Independent
#    Date: 6 hours ago
#    Link: https://www.milwaukeeindependent.com/articles/milwaukee-independent-emerges-wisconsin-leader-reporting-artificial-intelligence/
#    Snippet: As artificial intelligence reshapes global industries, raises ethical alarms, and floods the internet with generated content, few Wisconsin...
#
# 14. Oklahoma AG signs letter critical of congressional efforts to prohibit AI state regulation
#    Source: Oklahoma Voice
#    Date: 5 hours ago
#    Link: https://oklahomavoice.com/briefs/oklahoma-ag-signs-letter-critical-of-congressional-efforts-to-prohibit-ai-state-regulation/
#    Snippet: Oklahoma's attorney general is pushing back on a congressional effort to bar states from regulating artificial intelligence for the next...
#
# 15. Artificial Intelligence Creates More Jobs than It Replaces, Study Finds
#    Source: Hungarian Conservative
#    Date: 5 hours ago
#    Link: https://www.hungarianconservative.com/articles/tech/ai-jobs-study-employment-creation/
#    Snippet: Contrary to fears, AI is increasing jobs while transforming work, according to PwC's Global AI Jobs Barometer 2025.
#
# 16. The Superintelligent WhatsApp Team That Plans to Revolutionize Artificial Intelligence
#    Source: Al Día News
#    Date: 40 minutes ago
#    Link: https://aldianews.com/en/leadership/corporate/superintelligent-team
#    Snippet: Mark Zuckerberg created a WhatsApp group to recruit the new "superintelligence" team. Meta can and should surpass other tech companies.
#
# 17. Arkansas Supreme Court releases proposed rule for artificial intelligence
#    Source: Arkansas Advocate
#    Date: 20 hours ago
#    Link: https://arkansasadvocate.com/2025/06/09/arkansas-supreme-court-releases-proposed-rule-for-artificial-intelligence/
#    Snippet: The use of artificial intelligence in legal documents could violate Arkansas law or court rules, according to a proposed administrative...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


texts = [a["title"] + " " + a["snippet"] for a in articles]

# Compute TF-IDF matrix
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(texts)

# Compute cosine similarity matrix
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

# Calculate average cosine similarity for each article (excluding self)
avg_sim_scores = []
for i in range(len(articles)):
    sum_sim = np.sum(cosine_sim_matrix[i]) - cosine_sim_matrix[i][i]  # exclude self
    avg_sim = sum_sim / (len(articles) - 1) if len(articles) > 1 else 0
    avg_sim_scores.append(avg_sim)

# Attach the average similarity score to each article
for i, article in enumerate(articles):
    article['avg_similarity'] = avg_sim_scores[i]

# Rank the articles by their average similarity scores in descending order
ranked_articles = sorted(articles, key=lambda x: x['avg_similarity'], reverse=True)

# Output the ranking
for idx, art in enumerate(ranked_articles, 1):
    print(f"{idx}. {art['title']}")
    print(f"   Average similarity: {art['avg_similarity']:.4f}")
    print(f"   Source: {art['source']}")
    print(f"   Date: {art['date']}")
    print(f"   Link: {art['link']}\n")
# Out:
# 1. Is This Artificial Intelligence (AI) Stock Still a Buy?
#    Average similarity: 0.0834
#    Source: Nasdaq
#    Date: 5 hours ago
#    Link: https://www.nasdaq.com/articles/artificial-intelligence-ai-stock-still-buy
#
# 2. University releases proposed guidelines for artificial intelligence in teaching, learning, open to community feedback
#    Average similarity: 0.0775
#    Source: The Daily Texan
#    Date: 11 hours ago
#    Link: https://thedailytexan.com/2025/06/09/university-releases-proposed-guidelines-for-artificial-intelligence-in-teaching-learning-open-to-community-feedback/
#
# 3. Being Intelligent with Artificial Intelligence
#    Average similarity: 0.0741
#    Source: Dordt University
#    Date: 23 hours ago
#    Link: https://www.dordt.edu/news/being-intelligent-with-artificial-intelligence
#
# 4. Advanced AI suffers ‘complete accuracy collapse’ in face of complex problems, study finds | Artificial intelligence (AI)
#    Average similarity: 0.0727
#    Source: The Guardian
#    Date: 1 day ago
#    Link: https://www.theguardian.com/technology/2025/jun/09/apple-artificial-intelligence-ai-study-collapse
#
# 5. Arkansas Supreme Court releases proposed rule for artificial intelligence
#    Average similarity: 0.0699
#    Source: Arkansas Advocate
#    Date: 20 hours ago
#    Link: https://arkansasadvocate.com/2025/06/09/arkansas-supreme-court-releases-proposed-rule-for-artificial-intelligence/
#
# 6. How the WSJ is using artificial intelligence
#    Average similarity: 0.0677
#    Source: Talking Biz News
#    Date: 1 day ago
#    Link: https://talkingbiznews.com/media-news/how-the-wsj-is-using-artificial-intelligence/
#
# 7. Milwaukee Independent emerges as a Wisconsin leader for reporting on artificial intelligence
#    Average similarity: 0.0675
#    Source: Milwaukee Independent
#    Date: 6 hours ago
#    Link: https://www.milwaukeeindependent.com/articles/milwaukee-independent-emerges-wisconsin-leader-reporting-artificial-intelligence/
#
# 8. Oklahoma AG signs letter critical of congressional efforts to prohibit AI state regulation
#    Average similarity: 0.0604
#    Source: Oklahoma Voice
#    Date: 5 hours ago
#    Link: https://oklahomavoice.com/briefs/oklahoma-ag-signs-letter-critical-of-congressional-efforts-to-prohibit-ai-state-regulation/
#
# 9. Algoworks Launches as Global Artificial Intelligence (AI), Engineering Services and Experience Transformation Leader
#    Average similarity: 0.0585
#    Source: Business Wire
#    Date: 4 hours ago
#    Link: https://www.businesswire.com/news/home/20250609690407/en/Algoworks-Launches-as-Global-Artificial-Intelligence-AI-Engineering-Services-and-Experience-Transformation-Leader
#
# 10. Artificial intelligence, artificial support: Google buys new friends in Parliament
#    Average similarity: 0.0584
#    Source: Monthly Review
#    Date: 4 hours ago
#    Link: https://mronline.org/2025/06/10/artificial-intelligence-artificial-support-google-buys-new-friends-in-parliament/
#
# 11. Amazon invests historic $20 billion for artificial intelligence infrastructure in Pa.
#    Average similarity: 0.0573
#    Source: Pittsburgh Post-Gazette
#    Date: 19 hours ago
#    Link: https://www.post-gazette.com/business/tech-news/2025/06/09/amazon-srtificial-intelligence-shapiro-invest/stories/202506090047
#
# 12. Artificial Intelligence Creates More Jobs than It Replaces, Study Finds
#    Average similarity: 0.0543
#    Source: Hungarian Conservative
#    Date: 5 hours ago
#    Link: https://www.hungarianconservative.com/articles/tech/ai-jobs-study-employment-creation/
#
# 13. Texas A&M now offering ‘Artificial Intelligence and Business’ minor
#    Average similarity: 0.0542
#    Source: KBTX News 3
#    Date: 17 hours ago
#    Link: https://www.kbtx.com/2025/06/09/texas-am-now-offering-artificial-intelligence-business-minor/
#
# 14. ChatGPT is down - here's everything we know about the outage
#    Average similarity: 0.0520
#    Source: TechRadar
#    Date: 9 minutes ago
#    Link: https://www.techradar.com/news/live/chatgpt-down-june-10
#
# 15. Protests Against Artificial Intelligence Planned For Annecy Animation Fest
#    Average similarity: 0.0516
#    Source: Deadline
#    Date: 9 hours ago
#    Link: https://deadline.com/2025/06/artificial-intelligence-protests-planned-for-annecy-festival-1236428535/
#
# 16. The Superintelligent WhatsApp Team That Plans to Revolutionize Artificial Intelligence
#    Average similarity: 0.0482
#    Source: Al Día News
#    Date: 40 minutes ago
#    Link: https://aldianews.com/en/leadership/corporate/superintelligent-team
#
# 17. XNA’s new parking service features artificial intelligence
#    Average similarity: 0.0376
#    Source: Talk Business & Politics
#    Date: 22 hours ago
#    Link: https://talkbusiness.net/2025/06/xnas-new-parking-service-features-artificial-intelligence/
